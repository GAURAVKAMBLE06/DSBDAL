# %%
import pandas as pd

# %%
df=pd.read_csv('hostpital.csv')

# %%
df
# Out:
#                            Hospital name  Phone number  \
# 0            Abbotsford Private Hospital  08 9200 6282
# 1                        Adelaide Clinic  08 8269 8100
# 2           Adelaide Day Surgery Pty Ltd  08 8239 4900
# 3            Adelaide Eye & Laser Centre  08 8274 7000
# 4                   Adelaide Surgicentre  08 8211 0000
# ...                                  ...           ...
# 1006  Yarrawonga District Health Service  03 5743 8111
# 1007                       Yass Hospital  02 6220 2000
# 1008    Yea & District Memorial Hospital  03 5736 0400
# 1009                       York Hospital  08 9641 0200
# 1010                      Young Hospital  02 6382 8888
#
#               Street address            Suburb  Postcode State  \
# 0        61 Cambridge Street  West Leederville      6007    WA
# 1            33 Park Terrace         Gilberton      5081    SA
# 2           18 North Terrace          Adelaide      5000    SA
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1011 entries, 0 to 1010
# Data columns (total 15 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Hospital name                      1011 non-null   object
#  1   Phone number                       1007 non-null   object
#  2   Street address                     1010 non-null   object
#  3   Suburb                             1010 non-null   object
#  4   Postcode                           1011 non-null   int64
#  5   State                              1011 non-null   object
#  6   Local Hospital Network (LHN)       690 non-null    object
#  7   Primary Health Network area (PHN)  694 non-null    object
#  8   Website                            776 non-null    object
#  9   Description                        689 non-null    object
#  10  Sector                             1011 non-null   object
# ...

# %%
z=df[['Postcode','Latitude','Longitude','Hospital_ID']]

# %%
df.Postcode
# Out:
# 0       6007
# 1       5081
# 2       5000
# 3       5063
# 4       5067
#         ...
# 1006    3730
# 1007    2582
# 1008    3717
# 1009    6302
# 1010    2594
# Name: Postcode, Length: 1011, dtype: int64

# %%
z
# Out:
#       Postcode   Latitude   Longitude  Hospital_ID
# 0         6007 -31.940992  115.837344            1
# 1         5081 -34.906580  138.613167            2
# 2         5000 -34.922409  138.588817            3
# 3         5063 -34.940420  138.621500            4
# 4         5067 -34.917691  138.621022            5
# ...        ...        ...         ...          ...
# 1006      3730 -36.011547  146.006584         1007
# 1007      2582 -34.844072  148.906427         1008
# 1008      3717 -37.213634  145.430724         1009
# 1009      6302 -31.894392  116.757416         1010
# 1010      2594 -34.320383  148.288457         1011
#
# [1011 rows x 4 columns]

# %%
df.Postcode.min()
# Out:
# np.int64(810)

# %%
df.Postcode.max()
# Out:
# np.int64(7467)

# %%
df.notnull()
# Out:
#       Hospital name  Phone number  Street address  Suburb  Postcode  State  \
# 0              True          True            True    True      True   True
# 1              True          True            True    True      True   True
# 2              True          True            True    True      True   True
# 3              True          True            True    True      True   True
# 4              True          True            True    True      True   True
# ...             ...           ...             ...     ...       ...    ...
# 1006           True          True            True    True      True   True
# 1007           True          True            True    True      True   True
# 1008           True          True            True    True      True   True
# 1009           True          True            True    True      True   True
# 1010           True          True            True    True      True   True
#
# ...

# %%
x=pd.notnull(df["State"])

# %%
x
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 1006    True
# 1007    True
# 1008    True
# 1009    True
# 1010    True
# Name: State, Length: 1011, dtype: bool

# %%
from sklearn import preprocessing

# %%
y=df.fillna(df.Postcode.min())

# %%
y
# Out:
#                            Hospital name  Phone number  \
# 0            Abbotsford Private Hospital  08 9200 6282
# 1                        Adelaide Clinic  08 8269 8100
# 2           Adelaide Day Surgery Pty Ltd  08 8239 4900
# 3            Adelaide Eye & Laser Centre  08 8274 7000
# 4                   Adelaide Surgicentre  08 8211 0000
# ...                                  ...           ...
# 1006  Yarrawonga District Health Service  03 5743 8111
# 1007                       Yass Hospital  02 6220 2000
# 1008    Yea & District Memorial Hospital  03 5736 0400
# 1009                       York Hospital  08 9641 0200
# 1010                      Young Hospital  02 6382 8888
#
#               Street address            Suburb  Postcode State  \
# 0        61 Cambridge Street  West Leederville      6007    WA
# 1            33 Park Terrace         Gilberton      5081    SA
# 2           18 North Terrace          Adelaide      5000    SA
# ...

# %%
scaler = preprocessing.MinMaxScaler()

# %%
x = scaler.fit_transform(z)

# %%
x
# Out:
# array([[7.80681989e-01, 3.47537025e-01, 4.79682890e-02, 0.00000000e+00],
#        [6.41580291e-01, 2.56920386e-01, 5.49502366e-01, 9.90099010e-04],
#        [6.29412648e-01, 2.56436715e-01, 5.48966168e-01, 1.98019802e-03],
#        ...,
#        [4.36683191e-01, 1.86425942e-01, 6.99628101e-01, 9.98019802e-01],
#        [8.24996245e-01, 3.48960937e-01, 6.82286967e-02, 9.99009901e-01],
#        [2.67988583e-01, 2.74832248e-01, 7.62556693e-01, 1.00000000e+00]],
#       shape=(1011, 4))

# %%
frame=pd.DataFrame(x,columns=["Postcode","Latitude","longitude","Hospital_id"])

# %%
frame
# Out:
#       Postcode  Latitude  longitude  Hospital_id
# 0     0.780682  0.347537   0.047968      0.00000
# 1     0.641580  0.256920   0.549502      0.00099
# 2     0.629413  0.256437   0.548966      0.00198
# 3     0.638876  0.255886   0.549686      0.00297
# 4     0.639477  0.256581   0.549675      0.00396
# ...        ...       ...        ...          ...
# 1006  0.438636  0.223157   0.712309      0.99604
# 1007  0.266186  0.258830   0.776165      0.99703
# 1008  0.436683  0.186426   0.699628      0.99802
# 1009  0.824996  0.348961   0.068229      0.99901
# 1010  0.267989  0.274832   0.762557      1.00000
#
# [1011 rows x 4 columns]
