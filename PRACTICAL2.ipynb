# %%
import pandas as pd

# %%
df=pd.read_csv('student_dataset.csv')

# %%
df
# Out:
#      math score  reading score  writing score  placement score  \
# 0          66.0           90.0           64.0             95.0
# 1          79.0           90.0           73.0             90.0
# 2          74.0           75.0           64.0             91.0
# 3          70.0           83.0           74.0             89.0
# 4          67.0            NaN           76.0             95.0
# ..          ...            ...            ...              ...
# 195        64.0           79.0           73.0             86.0
# 196        79.0           77.0           74.0             96.0
# 197        61.0           86.0           60.0             86.0
# 198        65.0           90.0           80.0             91.0
# 199        70.0           93.0           62.0             96.0
#
#      club join year  placement offer count
# 0            2018.0                    3.0
# 1            2021.0                    3.0
# 2            2018.0                    2.0
# ...

# %%
df.columns
# Out:
# Index(['math score', 'reading score', 'writing score', 'placement score',
#        'club join year', 'placement offer count'],
#       dtype='object')

# %%
df.dropna()
# Out:
#      math score  reading score  writing score  placement score  \
# 0          66.0           90.0           64.0             95.0
# 1          79.0           90.0           73.0             90.0
# 2          74.0           75.0           64.0             91.0
# 5          80.0           90.0           73.0             87.0
# 6          66.0           77.0           79.0             85.0
# ..          ...            ...            ...              ...
# 195        64.0           79.0           73.0             86.0
# 196        79.0           77.0           74.0             96.0
# 197        61.0           86.0           60.0             86.0
# 198        65.0           90.0           80.0             91.0
# 199        70.0           93.0           62.0             96.0
#
#      club join year  placement offer count
# 0            2018.0                    3.0
# 1            2021.0                    3.0
# 2            2018.0                    2.0
# ...

# %%
df
# Out:
#      math score  reading score  writing score  placement score  \
# 0          66.0           90.0           64.0             95.0
# 1          79.0           90.0           73.0             90.0
# 2          74.0           75.0           64.0             91.0
# 3          70.0           83.0           74.0             89.0
# 4          67.0            NaN           76.0             95.0
# ..          ...            ...            ...              ...
# 195        64.0           79.0           73.0             86.0
# 196        79.0           77.0           74.0             96.0
# 197        61.0           86.0           60.0             86.0
# 198        65.0           90.0           80.0             91.0
# 199        70.0           93.0           62.0             96.0
#
#      club join year  placement offer count
# 0            2018.0                    3.0
# 1            2021.0                    3.0
# 2            2018.0                    2.0
# ...

# %%
df.isna()
# Out:
#      math score  reading score  writing score  placement score  \
# 0         False          False          False            False
# 1         False          False          False            False
# 2         False          False          False            False
# 3         False          False          False            False
# 4         False           True          False            False
# ..          ...            ...            ...              ...
# 195       False          False          False            False
# 196       False          False          False            False
# 197       False          False          False            False
# 198       False          False          False            False
# 199       False          False          False            False
#
#      club join year  placement offer count
# 0             False                  False
# 1             False                  False
# 2             False                  False
# ...

# %%
df.isna().sum().sum()
# Out:
# np.int64(30)

# %%
df.isna().sum()
# Out:
# math score               5
# reading score            5
# writing score            5
# placement score          5
# club join year           5
# placement offer count    5
# dtype: int64

# %%
df
# Out:
#      math score  reading score  writing score  placement score  \
# 0          66.0           90.0           64.0             95.0
# 1          79.0           90.0           73.0             90.0
# 2          74.0           75.0           64.0             91.0
# 3          70.0           83.0           74.0             89.0
# 4          67.0            NaN           76.0             95.0
# ..          ...            ...            ...              ...
# 195        64.0           79.0           73.0             86.0
# 196        79.0           77.0           74.0             96.0
# 197        61.0           86.0           60.0             86.0
# 198        65.0           90.0           80.0             91.0
# 199        70.0           93.0           62.0             96.0
#
#      club join year  placement offer count
# 0            2018.0                    3.0
# 1            2021.0                    3.0
# 2            2018.0                    2.0
# ...

# %%
df.describe()
# Out:
#        math score  reading score  writing score  placement score  \
# count  195.000000     195.000000     195.000000       195.000000
# mean    69.179487      85.523077      70.128205        93.148718
# std     10.207314      13.662849       6.195191        30.317792
# min      5.000000      10.000000      60.000000         5.000000
# 25%     64.000000      78.500000      64.000000        84.000000
# 50%     69.000000      85.000000      71.000000        91.000000
# 75%     74.000000      91.000000      76.000000        96.000000
# max    150.000000     200.000000      80.000000       400.000000
#
#        club join year  placement offer count
# count      195.000000             195.000000
# mean      2019.471795               2.046154
# std          1.113634               0.826696
# min       2018.000000               1.000000
# 25%       2018.500000               1.000000
# 50%       2019.000000               2.000000
# 75%       2020.000000               3.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   math score             195 non-null    float64
#  1   reading score          195 non-null    float64
#  2   writing score          195 non-null    float64
#  3   placement score        195 non-null    float64
#  4   club join year         195 non-null    float64
#  5   placement offer count  195 non-null    float64
# dtypes: float64(6)
# memory usage: 9.4 KB

# %%
df['math score']
# Out:
# 0      66.0
# 1      79.0
# 2      74.0
# 3      70.0
# 4      67.0
#        ...
# 195    64.0
# 196    79.0
# 197    61.0
# 198    65.0
# 199    70.0
# Name: math score, Length: 200, dtype: float64

# %%
df.dropna()
# Out:
#      math score  reading score  writing score  placement score  \
# 0          66.0           90.0           64.0             95.0
# 1          79.0           90.0           73.0             90.0
# 2          74.0           75.0           64.0             91.0
# 5          80.0           90.0           73.0             87.0
# 6          66.0           77.0           79.0             85.0
# ..          ...            ...            ...              ...
# 195        64.0           79.0           73.0             86.0
# 196        79.0           77.0           74.0             96.0
# 197        61.0           86.0           60.0             86.0
# 198        65.0           90.0           80.0             91.0
# 199        70.0           93.0           62.0             96.0
#
#      club join year  placement offer count
# 0            2018.0                    3.0
# 1            2021.0                    3.0
# 2            2018.0                    2.0
# ...

# %%
df.isna()
# Out:
#      math score  reading score  writing score  placement score  \
# 0         False          False          False            False
# 1         False          False          False            False
# 2         False          False          False            False
# 3         False          False          False            False
# 4         False           True          False            False
# ..          ...            ...            ...              ...
# 195       False          False          False            False
# 196       False          False          False            False
# 197       False          False          False            False
# 198       False          False          False            False
# 199       False          False          False            False
#
#      club join year  placement offer count
# 0             False                  False
# 1             False                  False
# 2             False                  False
# ...

# %%
df.isna().sum()
# Out:
# math score               5
# reading score            5
# writing score            5
# placement score          5
# club join year           5
# placement offer count    5
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
#      math score  reading score  writing score  placement score  \
# 3          70.0           83.0           74.0             89.0
# 4          67.0            NaN           76.0             95.0
# 11          NaN           93.0           80.0             87.0
# 19         80.0           92.0           61.0              NaN
# 29          NaN           94.0           61.0             84.0
# 31         62.0           76.0           79.0              NaN
# 32         64.0           75.0           71.0             89.0
# 43          NaN          200.0           60.0             96.0
# 54         63.0           77.0           62.0              NaN
# 55         77.0            NaN           76.0             84.0
# 58         61.0           88.0           61.0            100.0
# 72         67.0            NaN           68.0            250.0
# 86         60.0           76.0           68.0             91.0
# 87         71.0           95.0            NaN             84.0
# ...

# %%
df.drop(df[df.isnull().any(axis=1)].index)
# Out:
#      math score  reading score  writing score  placement score  \
# 0          66.0           90.0           64.0             95.0
# 1          79.0           90.0           73.0             90.0
# 2          74.0           75.0           64.0             91.0
# 5          80.0           90.0           73.0             87.0
# 6          66.0           77.0           79.0             85.0
# ..          ...            ...            ...              ...
# 195        64.0           79.0           73.0             86.0
# 196        79.0           77.0           74.0             96.0
# 197        61.0           86.0           60.0             86.0
# 198        65.0           90.0           80.0             91.0
# 199        70.0           93.0           62.0             96.0
#
#      club join year  placement offer count
# 0            2018.0                    3.0
# 1            2021.0                    3.0
# 2            2018.0                    2.0
# ...

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#      math score  reading score  writing score  placement score  \
# 0          66.0           90.0           64.0             95.0
# 1          79.0           90.0           73.0             90.0
# 2          74.0           75.0           64.0             91.0
# 5          80.0           90.0           73.0             87.0
# 6          66.0           77.0           79.0             85.0
# ..          ...            ...            ...              ...
# 195        64.0           79.0           73.0             86.0
# 196        79.0           77.0           74.0             96.0
# 197        61.0           86.0           60.0             86.0
# 198        65.0           90.0           80.0             91.0
# 199        70.0           93.0           62.0             96.0
#
#      club join year  placement offer count
# 0            2018.0                    3.0
# 1            2021.0                    3.0
# 2            2018.0                    2.0
# ...

# %%
df.isna()
# Out:
#      math score  reading score  writing score  placement score  \
# 0         False          False          False            False
# 1         False          False          False            False
# 2         False          False          False            False
# 5         False          False          False            False
# 6         False          False          False            False
# ..          ...            ...            ...              ...
# 195       False          False          False            False
# 196       False          False          False            False
# 197       False          False          False            False
# 198       False          False          False            False
# 199       False          False          False            False
#
#      club join year  placement offer count
# 0             False                  False
# 1             False                  False
# 2             False                  False
# ...

# %%
df.isna().sum()
# Out:
# math score               0
# reading score            0
# writing score            0
# placement score          0
# club join year           0
# placement offer count    0
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
col=['math score', 'reading score', 'writing score', 'placement score']

# %%
df.boxplot(col)
# Out:
# <Axes: >

# %%
import numpy as np

# %%
print(np.where(df["math score"]>90))
# Out:
# (array([54]),)

# %%
print(np.where(df["math score"]<60))
# Out:
# (array([ 9, 84]),)

# %%
fig,ax=plt.subplots(figsize=(18,10))
ax.scatter(df['placement score'],df['placement offer count'])
plt.show()

# %%
print(np.where((df['placement score']<50&(df['placement offer count']>1))))
# Out:
# (array([], dtype=int32),)

# %%
print(np.where((df['math score']<60&(df['placement offer count']>1))))
# Out:
# (array([], dtype=int32),)

# %%
from scipy import stats

# %%
z=np.abs(stats.zscore(df['math score']))

# %%
print(z)
# Out:
# 0     0.651751
# 1     0.722357
# 2     0.472519
# 3     0.472519
# 4     0.972195
#         ...
# 94    0.526832
# 95    1.151426
# 96    1.276345
# 97    0.222681
# 98    0.847276
# Name: math score, Length: 92, dtype: float64

# %%
threshold=0.18

# %%
outliers=np.where(z<threshold)
outliers
# Out:
# (array([ 7, 17, 24, 35, 37, 42, 49, 57, 61, 67, 79, 84]),)

# %%
sorted_rsscore=sorted(df['reading score'])

# %%
sorted_rsscore
# Out:
# [15,
#  75,
#  75,
#  76,
#  76,
#  76,
#  76,
#  76,
#  77,
#  77,
#  78,
#  78,
#  78,
#  78,
#  78,
#  79,
#  79,
#  79,
#  80,
#  80,
#  80,
#  80,
#  80,
#  81,
#  81,
#  81,
#  81,
#  82,
#  82,
#  82,
#  82,
#  83,
#  83,
#  83,
#  84,
#  84,
#  85,
#  85,
#  85,
#  85,
#  85,
#  85,
#  86,
#  86,
#  86,
#  86,
#  86,
#  86,
#  87,
#  87,
#  87,
#  87,
#  87,
#  88,
#  88,
#  88,
#  88,
#  88,
#  89,
#  89,
#  89,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  91,
#  91,
#  92,
#  92,
#  92,
#  92,
#  92,
#  93,
#  93,
#  93,
#  93,
#  93,
#  94,
#  94,
#  94,
#  95,
#  95,
#  95,
#  120]

# %%
q1=np.percentile(sorted_rsscore,25)
q3=np.percentile(sorted_rsscore,75)

# %%
print(q1,q3)
# Out:
# 80.75 90.0

# %%
IQR=q3-q1

# %%
lwr_bound=q1-(1.5*IQR)
upr_bound=q3+(1.5*IQR)
print(lwr_bound,upr_bound)
# Out:
# 66.875 103.875

# %%
r_outliers=[]
for i in sorted_rsscore:
    if(i<lwr_bound or i>upr_bound):
        r_outliers.append(i)
print(r_outliers)
# Out:
# [15, 120]

# %%
col1=['reading score']

# %%
df.boxplot(col1)
# Out:
# <Axes: >

# %%
plt.show()

# %%
df['math score'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
plt.show()

# %%
df['log_maths']=np.log10(df['math score'])

# %%
df['log_maths'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
plt.show()
